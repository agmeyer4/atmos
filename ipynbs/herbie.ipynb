# %%
import os
import sys
import numpy as np
import xarray as xr
from matplotlib import pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.img_tiles as cimgt
from herbie import Herbie
sys.path.append('/uufs/chpc.utah.edu/common/home/u0890904/LAIR_1/atmos')
from utils import datetime_utils

# %%
wbb_loc = {'lat': 40.7608, 'lon': -111.8910}

# %%
dtr = datetime_utils.DateTimeRange('2024-07-29', '2024-07-29')
dates = dtr.get_dates_in_range()
hours = np.arange(0, 24, 1)

# %%
date = dates[0]
for hour in hours:
    dtstr = f"{date} {hour:02d}:00"
    H = Herbie(
        dtstr,  # Model initialization time
        model="hrrr",  # Model name
        fxx=0,  # Forecast step, in hours
        product="sfc",  # Model product
    )
#H.download(r":COLMD|MASSDEN:",save_dir = '/uufs/chpc.utah.edu/common/home/lin-group9/agm/HRRR/SLV_Smoke')
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 01:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 02:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 03:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 04:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 05:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 06:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 07:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 08:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 09:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ...

# %%
date = dates[0]
hour = hours[0]
dtstr = f"{date} {hour:02d}:00"
H = Herbie(
    dtstr,  # Model initialization time
    model="hrrr",  # Model name
    fxx=0,  # Forecast step, in hours
    product="sfc",  # Model product
)
dss = H.xarray(r":COLMD|MASSDEN:",save_dir = '/uufs/chpc.utah.edu/common/home/lin-group9/agm/HRRR/SLV_Smoke', verbose=True)
ds = xr.merge(dss)
ds = ds.drop_vars([coord for coord in ds.coords if coord not in ['time', 'latitude', 'longitude']])
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Jul-29 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# 📇 Download subset: ▌▌Herbie HRRR model sfc product initialized 2024-Jul-29 00:00 UTC F00 ┊ source=aws
#  cURL from https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr.20240729/conus/hrrr.t00z.wrfsfcf00.grib2
#   76  :MASSDEN:8 m above ground:anl
#   109 :COLMD:entire atmosphere (considered as a single layer):anl
# 💾 Saved the subset to /uufs/chpc.utah.edu/common/home/lin-group9/agm/HRRR/SLV_Smoke/hrrr/20240729/subset_acefb480__hrrr.t00z.wrfsfcf00.grib2
# Note: Returning a list of [2] xarray.Datasets because cfgrib opened with multiple hypercubes.

# %%
ds = xr.open_dataset('/uufs/chpc.utah.edu/common/home/lin-group9/agm/HRRR/SLV_Smoke/hrrr/20240729/subset_acefb480__hrrr.t00z.wrfsfcf00.grib2')
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (y: 1059, x: 1799)
# Coordinates:
#     time                   datetime64[ns] ...
#     step                   timedelta64[ns] ...
#     heightAboveGround      float64 ...
#     latitude               (y, x) float64 ...
#     longitude              (y, x) float64 ...
#     valid_time             datetime64[ns] ...
#     atmosphereSingleLayer  float64 ...
# Dimensions without coordinates: y, x
# Data variables:
#     mdens                  (y, x) float32 ...
#     tc_mdens               (y, x) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2024-11-19T13:38 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
points = (wbb_loc['lon'], wbb_loc['lat'])
ds.herbie.nearest_points(points)
# Out:
# <xarray.Dataset>
# Dimensions:              (point: 1)
# Coordinates:
#     time                 datetime64[ns] 2024-07-29
#     latitude             float64 40.75
#     longitude            float64 248.1
#     metpy_crs            object Projection: lambert_conformal_conic
#     y                    float64 3.447e+05
#     x                    float64 -1.21e+06
#   * point                (point) object None
#     point_latitude       (point) float64 40.76
#     point_longitude      (point) float64 -111.9
# Data variables:
#     tc_mdens             (point) float32 9.52e-05
#     gribfile_projection  (point) object None
#     mdens                (point) float32 8.08e-09
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
# ...

# %%
# data_extent={'lon_min':-115.2,
#             'lon_max':-108.6,
#             'lat_min':38.3,
#             'lat_max':45.1} 
plot_da = ds['tc_mdens']
ds['gribfile_projection'].attrs
# Out:
# {'crs_wkt': 'PROJCRS["unknown",BASEGEOGCRS["unknown",DATUM["unknown",ELLIPSOID["unknown",6371229,0,LENGTHUNIT["metre",1,ID["EPSG",9001]]]],PRIMEM["Greenwich",0,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8901]]],CONVERSION["unknown",METHOD["Lambert Conic Conformal (2SP)",ID["EPSG",9802]],PARAMETER["Latitude of false origin",38.5,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8821]],PARAMETER["Longitude of false origin",262.5,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8822]],PARAMETER["Latitude of 1st standard parallel",38.5,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8823]],PARAMETER["Latitude of 2nd standard parallel",38.5,ANGLEUNIT["degree",0.0174532925199433],ID["EPSG",8824]],PARAMETER["Easting at false origin",0,LENGTHUNIT["metre",1],ID["EPSG",8826]],PARAMETER["Northing at false origin",0,LENGTHUNIT["metre",1],ID["EPSG",8827]]],CS[Cartesian,2],AXIS["(E)",east,ORDER[1],LENGTHUNIT["metre",1,ID["EPSG",9001]]],AXIS["(N)",north,ORDER[2],LENGTHUNIT["metre",1,ID["EPSG"
# ...

# %%
map_extent={'lon_min':-117.2,
            'lon_max':-106.6,
            'lat_min':36.3,
            'lat_max':47.1} 

plot_da = ds['tc_mdens']

#pcolormesh_kwargs = {'cmap':'viridis','vmin':0,'vmax':0.01,'alpha':0.7}
#proj = ccrs.PlateCarree()
proj = ccrs.LambertConformal(central_longitude=ds['gribfile_projection'].attrs['longitude_of_central_meridian'],  
                             central_latitude=ds['gribfile_projection'].attrs['latitude_of_projection_origin'],
                             standard_parallels=[ds['gribfile_projection'].attrs['standard_parallel']])

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection = proj)
ax.set_extent([map_extent['lon_min'],map_extent['lon_max'],map_extent['lat_min'],map_extent['lat_max']],crs=proj)

request = cimgt.GoogleTiles(style='street')
scale = 10.0 # prob have to adjust this
ax.add_image(request,int(scale))
#ax.contourf(ds['gridlon_0'],ds['gridlat_0'],plot_da,transform=proj)#,**pcolormesh_kwargs)
plot_da.plot.pcolormesh('gridlon_0','gridlat_0',ax = ax)#,**pcolormesh_kwargs)
ax.coastlines()
ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.STATES)
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Cell In[15], line 10
#       6 plot_da = ds['tc_mdens']
#       8 #pcolormesh_kwargs = {'cmap':'viridis','vmin':0,'vmax':0.01,'alpha':0.7}
#       9 #proj = ccrs.PlateCarree()
# ---> 10 proj = ccrs.LambertConformal(central_longitude=ds['gribfile_projection'].attrs['longitude_of_central_meridian'],
#      11                              central_latitude=ds['gribfile_projection'].attrs['latitude_of_projection_origin'],
#      12                              standard_parallels=[ds['gribfile_projection'].attrs['standard_parallel']])
#      14 fig = plt.figure(figsize=(10,10))
#      15 ax = plt.axes(projection = proj)
#
# ...
